# %% [markdown]
# # 处理并分析城市酒店与度假酒店的预定信息
# ![131615464432_.pic.jpg](attachment:131615464432_.pic.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 读取数据并查看数据概览
data = pd.read_csv("../data/hotel_bookings.csv")
print(data.shape)
# Out:
# (119390, 32)

# %% [markdown]
# hotel                             酒店类型（假日or城市）
# is_canceled                       是否取消（0=否，1=是）
# lead_time                         预订日期-到达日期之间，经过的天数
# arrival_date_year                 抵达的年
# arrival_date_month                抵达的月
# arrival_date_week_number          抵达的周次
# arrival_date_day_of_month         抵达的日
# stays_in_weekend_nights           呆了几个周末天数
# stays_in_week_nights              呆了几个周中天数
# adults                            成人数量
# children                          儿童数量
# babies                            婴儿数量
# meal                              用餐：早餐BB：指包含在酒店入住期间的每日早餐，包括离开酒店当天的早餐。
#                                        早晚餐HB：指包含在酒店入住期间的早餐和晚餐。
#                                        三餐FB：指包含在酒店入住期间的每日三餐，但是不包含酒水。
#                                        一价全包AI：指包含在酒店入住期间的一切餐饮，每日三餐和酒水。
# country                           国家
# market_segment                    细分市场：TA代表travel agents旅行社；TO代表 tour operators旅游经营者
# distribution_channel              分销渠道：
# is_repeated_guest                 是否为老客：老客为1，新客为0
# previous_cancellations            之前的取消数
# previous_bookings_not_canceled    之前的未取消数
# reserved_room_type                预留的房间的类型
# assigned_room_type                分配的房间类型
# booking_changes                   119390
# deposit_type                      119390
# agent                             103050
# company                             6797
# days_in_waiting_list              119390
# customer_type                     119390
# adr                               119390
# required_car_parking_spaces       119390
# total_of_special_requests         119390
# reservation_status                119390
# reservation_status_date
#
# ![image-3.png](attachment:image-3.png)

# %%
# #数据信息，一共32列
# data.info()
# # 数据整体描述
# data.describe()
# 查看各列的非空数据量
data.count()
# Out:
# hotel                             119390
# is_canceled                       119390
# lead_time                         119390
# arrival_date_year                 119390
# arrival_date_month                119390
# arrival_date_week_number          119390
# arrival_date_day_of_month         119390
# stays_in_weekend_nights           119390
# stays_in_week_nights              119390
# adults                            119390
# children                          119386
# babies                            119390
# meal                              119390
# country                           118902
# market_segment                    119390
# distribution_channel              119390
# is_repeated_guest                 119390
# previous_cancellations            119390
# previous_bookings_not_canceled    119390
# reserved_room_type                119390
# assigned_room_type                119390
# booking_changes                   119390
# deposit_type                      119390
# ...
